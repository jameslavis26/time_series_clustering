# %%
from experiments import Experiment

# %%
experiment = Experiment("experiment.yaml")

# %%
experiment.run_experiments()
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 experiment.run_experiments()
#
# File ~/Repo/PhD Repo/time_series_clustering/experiment_framework/experiments/experiment.py:173, in Experiment.run_experiments(self)
#     172 def run_experiments(self):
# --> 173     for sub_exp in tqdm(self.sub_experiments):
#     174         sub_exp.run_experiment()
#     175         self.completed_experiments.append(sub_exp)
#
# File ~/Repo/PhD Repo/time_series_clustering/venv/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Repo/PhD Repo/time_series_clustering/experiment_framework/experiments/experiment.py:154, in Experiment.parse_experiments(self, experiments)
#     152 model_class = model_library[models[model_name]["model"]]
#     153 model_params = models[model_name]["parameters"] if "parameters" in models[model_name] else {}
# --> 154 kernel_names = models[model_name]["kernels"]
#     155 model_hparams = models[model_name]["hyperparameters"] if "hyperparameters" in models[model_name] else None
#     157 yield SubExperiment(
#     158     experiment_name=experiment,
#     159     dataset=dataset,
#    (...)    169     kernels={k:v for k, v in kernels.items() if k in kernel_names}
#     170 )
#
# KeyError: 'kernels'

# %%
experiment.get_results()
# Out:
#                            MeanSquaredError      reg  k1_bandwidth  \
# exp_name
# lorenz_1 - model_krr               1.671870  0.00054           100
# lorenz_1 - model_rascutti          0.118257      NaN           100
#
#                            k2_bandwidth  k3_bandwidth noise_mean  \
# exp_name
# lorenz_1 - model_krr                 50            50  [0, 0, 0]
# lorenz_1 - model_rascutti            50            50  [0, 0, 0]
#
#                            noise_covariance            x0    dt   T  rho  \
# exp_name
# lorenz_1 - model_krr                   0.01  [10, 10, 10]  0.01  10   28
# lorenz_1 - model_rascutti              0.01  [10, 10, 10]  0.01  10   28
#
#                            sigma  beta       lam
# exp_name
# lorenz_1 - model_krr          10   2.4       NaN
# lorenz_1 - model_rascutti     10   2.4  0.001466

# %%
experiment.plots
# Out:
# [None]

# %%
experiment.report_cols
# Out:
# [['MeanSquaredError']]

# %%
# experiment.generate_plots()
experiment.save()

# %%
experiment.generate_reports()
# Out:
#                            MeanSquaredError
# exp_name
# lorenz_1 - model_krr               1.671870
# lorenz_1 - model_rascutti          0.118257
