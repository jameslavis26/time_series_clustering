# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

from time_series.data_handlers.time_series_converter import to_time_series

from time_series.data_generators import LorenzGenerator
from time_series.data_handlers import TimeSeriesData

from time_series.kernels import GaussianKernel

from time_series.models import KernelRidgeRegression

# %%
# Data
t, data = LorenzGenerator(
    noise_covariance=0.01,
    x0=[10, 10, 10],
    dt=0.01,
    T=10,
    rho=28,
    sigma=10,
    beta=2.4
)()

dataset = TimeSeriesData(
    data[:-1],
    data[1:],
    train_val_test_split=[0.5, 0.2, 0.3],
    t=t
)
